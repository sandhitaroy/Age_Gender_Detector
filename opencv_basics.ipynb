# %%
import cv2
from matplotlib import pyplot as plt

# %%
img=cv2.imread("pics/p1.jpg",1)

# %%
plt.imshow(img)

# %%
img2=cv2.imread("pics/p2.jpg",1)

# %%
res=img+img2

# %%
plt.imshow(img2+img)

# %%
plt.imshow(img2*img)

# %%
plt.imshow(img2-img)

# %%
plt.imshow(img2/img)
# Out:
# C:\Users\Soma Roy\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
